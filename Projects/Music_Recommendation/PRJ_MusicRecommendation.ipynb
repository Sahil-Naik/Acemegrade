# %% [markdown]
# # Project - Music Recommendation

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import Recommenders

# %% [markdown]
# ### Loading 'triplets_file' dataset

# %%
df1 = pd.read_csv('dataset/triplets_file.csv')
print('Shape of dataset-1 is: {}'.format(df1.shape))
# Out:
# Shape of dataset-1 is: (2000000, 3)

# %%
df1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
df1.isnull().sum()
# Out:
# user_id         0
# song_id         0
# listen_count    0
# dtype: int64

# %% [markdown]
# ### Loading 'song' dataset

# %%
df2 = pd.read_csv('dataset/song_data.csv')
print('Shape of dataset-2 is: {}'.format(df2.shape))
# Out:
# Shape of dataset-2 is: (1000000, 5)

# %%
df2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %% [markdown]
# ### Combining both datasets to create one dataset

# %%
df = pd.merge(df1, df2.drop_duplicates(['song_id']), on='song_id', how='left')
print("Shape of merged dataset is: {}".format(df.shape))
# Out:
# Shape of merged dataset is: (2000000, 7)

# %%
df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
print("Length of dataset-1 is: {}".format(len(df1)))
print("Length of dataset-2 is: {}".format(len(df2)))
print("Length of merged dataset is: {}".format(len(df)))
# Out:
# Length of dataset-1 is: 2000000
# Length of dataset-2 is: 1000000
# Length of merged dataset is: 2000000

# %% [markdown]
# ### Selecting only 50,000 record for creating the model

# %%
df = df.head(50000)
print("Length of new dataset is: {}".format(len(df)))
# Out:
# Length of new dataset is: 50000

# %% [markdown]
# ### Creating new feature combining title and artist name

# %%
df['song'] = df['title']+' - '+df['artist_name']
df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %% [markdown]
# ### Number of times a song was listened, based on group of song

# %%
df_grouped = df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
df_grouped.head()
# Out:
#                                                 song  listen_count
# 0  #!*@ You Tonight [Featuring R. Kelly] (Explici...             1
# 1                           #40 - DAVE MATTHEWS BAND             7
# 2                                & Down - Boys Noize            13
# 3                          ' Cello Song - Nick Drake             3
# 4                        '97 Bonnie & Clyde - Eminem             5

# %% [markdown]
# ### Total counts

# %%
grouped_sum = df_grouped['listen_count'].sum()
grouped_sum
# Out:
# 50000

# %% [markdown]
# ### Most popular song by percentage

# %%
df_grouped['percentage'] = (df_grouped['listen_count'] / grouped_sum ) * 100
df_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count  \
# 6682                           Sehr kosmisch - Harmonia           204
# 8509                                       Undo - Björk           182
# 1936  Dog Days Are Over (Radio Edit) - Florence + Th...           173
# 9256                     You're The One - Dwight Yoakam           169
# 6348                            Revelry - Kings Of Leon           166
# ...                                                 ...           ...
# 9290                    Your Time Has Come - Audioslave             1
# 9300  Zebra (full-length/album version) - John Butle...             1
# 9311                                clouding - Four Tet             1
# 9312                              high fives - Four Tet             1
# 9321                               the Love Song - K-OS             1
#
#       percentage
# 6682       0.408
# 8509       0.364
# 1936       0.346
# 9256       0.338
# 6348       0.332
# ...          ...
# 9290       0.002
# 9300       0.002
# 9311       0.002
# 9312       0.002
# 9321       0.002
#
# [9325 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Loading popularity recommendation engine

# %%
engine = Recommenders.popularity_recommender_py()
engine.create(df, 'user_id', 'song')

# %% [markdown]
# ### Displaying top 10 popular song for user 3

# %%
engine.recommend(df['user_id'][3])
# Out:
#                                        user_id  \
# 6682  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8509  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1936  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9256  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6348  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6671  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3372  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2532  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8287  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3254  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 6682                           Sehr kosmisch - Harmonia    204   1.0
# 8509                                       Undo - Björk    182   2.0
# 1936  Dog Days Are Over (Radio Edit) - Florence + Th...    173   3.0
# 9256                     You're The One - Dwight Yoakam    169   4.0
# 6348                            Revelry - Kings Of Leon    166   5.0
# 6671                              Secrets - OneRepublic    158   6.0
# 3372  Horn Concerto No. 4 in E flat K495: II. Romanc...    134   7.0
# 2532                     Fireflies - Charttraxx Karaoke    128   8.0
# 8287                                 Tive Sim - Cartola    117   9.0
# 3254                           Hey_ Soul Sister - Train    109  10.0

# %% [markdown]
# ### Displaying top 10 popular song for user 250

# %%
engine.recommend(df['user_id'][250])
# Out:
#                                        user_id  \
# 6682  17aa9f6dbdf753831da8f38c71b66b64373de613
# 8509  17aa9f6dbdf753831da8f38c71b66b64373de613
# 1936  17aa9f6dbdf753831da8f38c71b66b64373de613
# 9256  17aa9f6dbdf753831da8f38c71b66b64373de613
# 6348  17aa9f6dbdf753831da8f38c71b66b64373de613
# 6671  17aa9f6dbdf753831da8f38c71b66b64373de613
# 3372  17aa9f6dbdf753831da8f38c71b66b64373de613
# 2532  17aa9f6dbdf753831da8f38c71b66b64373de613
# 8287  17aa9f6dbdf753831da8f38c71b66b64373de613
# 3254  17aa9f6dbdf753831da8f38c71b66b64373de613
#
#                                                    song  score  Rank
# 6682                           Sehr kosmisch - Harmonia    204   1.0
# 8509                                       Undo - Björk    182   2.0
# 1936  Dog Days Are Over (Radio Edit) - Florence + Th...    173   3.0
# 9256                     You're The One - Dwight Yoakam    169   4.0
# 6348                            Revelry - Kings Of Leon    166   5.0
# 6671                              Secrets - OneRepublic    158   6.0
# 3372  Horn Concerto No. 4 in E flat K495: II. Romanc...    134   7.0
# 2532                     Fireflies - Charttraxx Karaoke    128   8.0
# 8287                                 Tive Sim - Cartola    117   9.0
# 3254                           Hey_ Soul Sister - Train    109  10.0

# %% [markdown]
# ### Item similarity recommendation

# %%
engine_i = Recommenders.item_similarity_recommender_py()
engine_i.create(df, 'user_id', 'song')

# %% [markdown]
# ### Displaying similar item for user 3

# %%
user_items = engine_i.get_user_items(df['user_id'][3])
for item in user_items:
    print(item)
# Out:
# The Cove - Jack Johnson
# Entre Dos Aguas - Paco De Lucia
# Stronger - Kanye West
# Constellations - Jack Johnson
# Learn To Fly - Foo Fighters
# Apuesta Por El Rock 'N' Roll - Héroes del Silencio
# Paper Gangsta - Lady GaGa
# Stacked Actors - Foo Fighters
# Sehr kosmisch - Harmonia
# Heaven's gonna burn your eyes - Thievery Corporation feat. Emiliana Torrini
# Let It Be Sung - Jack Johnson / Matt Costa / Zach Gill / Dan Lebowitz / Steve Adams
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - Puff Daddy
#
# no. of unique songs in the training set: 9325
# Non zero values in cooccurence_matrix :76631
#                                     user_id  \
# 0  17aa9f6dbdf753831da8f38c71b66b64373de613
# 1  17aa9f6dbdf753831da8f38c71b66b64373de613
# 2  17aa9f6dbdf753831da8f38c71b66b64373de613
# 3  17aa9f6dbdf753831da8f38c71b66b64373de613
# 4  17aa9f6dbdf753831da8f38c71b66b64373de613
# 5  17aa9f6dbdf753831da8f38c71b66b64373de613
# 6  17aa9f6dbdf753831da8f38c71b66b64373de613
# 7  17aa9f6dbdf753831da8f38c71b66b64373de613
# 8  17aa9f6dbdf753831da8f38c71b66b64373de613
# 9  17aa9f6dbdf753831da8f38c71b66b64373de613
#
#                                                 song     score rank
# 0                                La Llorona - Beirut  0.078240    1
# 1                    Man Who Make You Sick - Man Man  0.077764    2
# 2                            Rabbit Habits - Man Man  0.077337    3
# 3               Again & Again - the bird and the bee  0.077287    4
# 4                             Banana Ghost - Man Man  0.074059    5
# 5                    Girl Sailor (Album) - The Shins  0.072373    6
# 6                      Last Day Of Magic - The Kills  0.072266    7
# 7                     Mild Child (Album) - The Shins  0.072245    8
# 8  Werewolf (on the hood of yer heartbreak) - Man...  0.071609    9
# 9                   Jumpers (Album) - Sleater-kinney  0.070409   10

# %% [markdown]
# ---

# %% [markdown]
# ### Recommending based on song name - test1

# %%
engine_i.get_similar_items(['Banana Ghost - Man Man', 'Rabbit Habits - Man Man'])
# Out:
# no. of unique songs in the training set: 9325
# Non zero values in cooccurence_matrix :1545
#   user_id                                          song     score rank
# 0                               Acadian Coast - Soltero  0.403846    1
# 1                        Skinning the Drum - themselves  0.361111    2
# 2                       Man Who Make You Sick - Man Man  0.337500    3
# 3                         Last Day Of Magic - The Kills  0.333333    4
# 4                                  Gold Teeth - Man Man  0.330357    5
# 5                  Living In Colour - Frightened Rabbit  0.315385    6
# 6                               Hubcap - Sleater-kinney  0.291667    7
# 7          The Spirit Of Giving - The New Pornographers  0.291667    8
# 8                      Please_ Before I Go - Derek Webb  0.291667    9
# 9               Grace Cathedral Hill - The Decemberists  0.291667   10

# %% [markdown]
# ### Recommending based on song name - test2

# %%
engine_i.get_similar_items(['La Llorona - Beirut'])
# Out:
# no. of unique songs in the training set: 9325
# Non zero values in cooccurence_matrix :797
#   user_id                                song     score rank
# 0                       On a Bayonet - Beirut  0.625000    1
# 1                      The Concubine - Beirut  0.600000    2
# 2               Postcards From Italy - Beirut  0.571429    3
# 3                            My Wife - Beirut  0.555556    4
# 4                     A Sunday Smile - Beirut  0.538462    5
# 5          Mount Wroclai (Idle Days) - Beirut  0.500000    6
# 6                          The Shrew - Beirut  0.500000    7
# 7                        Brandenburg - Beirut  0.454545    8
# 8                     Prenzlauerberg - Beirut  0.444444    9
# 9                 The Gulag Orkestar - Beirut  0.400000   10

# %% [markdown]
# ---
